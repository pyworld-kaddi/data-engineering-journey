# %%
class Engine:

    def start(self):
        print("Engine Started")

class Car:

    def __init__(self):
        self.engine = Engine()

car1 = Car()

car1.engine.start()
# Out:
# Engine Started

# %%
class Engine:

    def start(self):
        print("Engine Started")

class Car:

    def __init__(self):
        self.engine = Engine()

    def start_car(self):
        self.engine.start()
        print("Car Started")

car1 = Car()
car1.start_car()
# Out:
# Engine Started
# Car Started

# %%
class Battery:

    def charge(self):
        print("Battery Charging")

class Mobile:

    def __init__(self):
        self.battery = Battery()

    def charge_mobile(self):
        self.battery.charge()
        print("Mobile Ready")

mobile1 = Mobile()

mobile1.charge_mobile()
# Out:
# Battery Charging
# Mobile Ready

# %%
class Laptop:
   

    def brand(self):
        return self.b_name

class Employee:

    def __init__(self,name,b_name):
        self.name = name
        self.laptop = Laptop()
        self.laptop.brand(b_name)

    def details(self):
        print(self.name,"uses",self.laptop.brand())


employee1=Employee("Arun","Dell")


employee1.details()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 18
#      14     def details(self):
#      15         print(self.name,"uses",self.laptop.brand())
#      16
#      17
# ---> 18 employee1=Employee("Arun","Dell")
#      19
#      20
#      21 employee1.details()
#
# Cell In[9], line 12, in Employee.__init__(self, name, b_name)
#       9     def __init__(self,name,b_name):
#      10         self.name = name
#      11         self.laptop = Laptop()
# ---> 12         self.laptop.brand(b_name)
#
# TypeError: Laptop.brand() takes 1 positional argument but 2 were given
