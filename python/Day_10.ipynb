# %%
file = open("names.txt","r")

print(file.readline())
print(file.readline())

file.close()
# Out:
# Arun
#
# Bala

# %%
file = open("names.txt","r")

print(file.read())

file.close()
# Out:
# Arun
# Bala
# Kumar

# %%
file = open("names.txt","r")

print(file.readlines())

file.close()
# Out:
# ['Arun\n', 'Bala\n', 'Kumar']

# %%
file = open("names.txt","r")

lines = file.readlines()

print(len(lines))
print(lines[1])

file.close()
# Out:
# 3
# Bala
